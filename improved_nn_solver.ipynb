# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split
from torchvision.transforms import ToTensor
from torch.utils.data import Dataset
import numpy as np
import pandas as pd

# %%
class MysteryDataset(Dataset):
    def __init__(self, csv_file, is_test=False):
        self.is_test = is_test
        df = pd.read_csv(csv_file)
        
        self.ids = df.iloc[:, 0].values
        if self.is_test:
            self.X = df.iloc[:, 1:].values.astype(np.float32)
            self.y = None
        else:
            self.X = df.iloc[:, 1:-1].values.astype(np.float32)
            self.y = df.iloc[:, -1].values.astype(np.int64) 

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        features = torch.tensor(self.X[idx])
        
        if self.is_test:
            return features
        else:
            label = torch.tensor(self.y[idx])
            return features, label

# %%
# import data from files
full_tensor = MysteryDataset("data/train.csv", 0)
test_data_tensor = MysteryDataset("data/test.csv", 1)

train_size = int(0.8 * len(full_tensor))
val_size = len(full_tensor) - train_size
train_data_tensor, val_data_tensor = random_split(full_tensor, [train_size, val_size])

# %%
# create data loaders
train_loader = DataLoader(dataset=train_data_tensor, batch_size=64)
val_loader = DataLoader(dataset=val_data_tensor, batch_size=64)
test_loader = DataLoader(dataset=test_data_tensor, batch_size=64)

# %%
for X, y in train_loader:
    print(max(y), end=' ')
# Out:
# tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(3) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(3) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(3) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4) tensor(4)

# %%
device = torch.cuda.current_device().type if torch.cuda.is_available() else "cpu"

# %%
input_dim = 205

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()

        self.linear_relu_stack = nn.Sequential(
            nn.Linear(205, 512), 
            nn.ReLU(),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Linear(128, 5),
        )
    

    def forward(self, x):
        # pass through the layers
        logits = self.linear_relu_stack(x)
        # return the logits
        return logits

# %%
model = NeuralNetwork().to(device)
learning_rate = 1e-3
batch_size = 64
epochs = 5

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %%
def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if batch % 100 == 0:
            loss, current = loss.item(), batch * batch_size + len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")




def validation_loop(dataloader, model, loss_fn):
    # Set the model to evaluation mode - important for batch normalization and dropout layers
    # Unnecessary in this situation but added for best practices
    model.eval()
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    # Evaluating the model with torch.no_grad() ensures that no gradients are computed during test mode
    # also serves to reduce unnecessary gradient computations and memory usage for tensors with requires_grad=True
    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size
    print(f"Validation Error: Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

def test_loop(dataloader, model, output_file):
    # Set the model to evaluation mode - important for batch normalization and dropout layers
    # Unnecessary in this situation but added for best practices
    model.eval()
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0
    all_preds = []

    # Evaluating the model with torch.no_grad() ensures that no gradients are computed during test mode
    # also serves to reduce unnecessary gradient computations and memory usage for tensors with requires_grad=True
    with torch.no_grad():
        for X in dataloader:
            preds = model(X)
            all_preds.extend(preds.argmax(1).numpy())

    df = pd.DataFrame({
        "id": range(len(all_preds)), # Or use actual IDs if you saved them
        "label": all_preds
    })
    df.to_csv(output_file, index=False)
    print(f"Saved predictions to {output_file}")

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

epochs = 30
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loop(train_loader, model, loss_fn, optimizer)
    validation_loop(val_loader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 1.576370  [   64/ 6400]
# Validation Error: Accuracy: 50.7%, Avg loss: 1.327472
#
# Epoch 2
# -------------------------------
# loss: 1.375606  [   64/ 6400]
# Validation Error: Accuracy: 50.7%, Avg loss: 1.275387
#
# Epoch 3
# -------------------------------
# loss: 1.335224  [   64/ 6400]
# Validation Error: Accuracy: 51.1%, Avg loss: 1.236730
#
# Epoch 4
# -------------------------------
# loss: 1.302620  [   64/ 6400]
# Validation Error: Accuracy: 52.6%, Avg loss: 1.201497
#
# Epoch 5
# -------------------------------
# loss: 1.271913  [   64/ 6400]
# Validation Error: Accuracy: 54.6%, Avg loss: 1.168105
#
# Epoch 6
# -------------------------------
# loss: 1.240233  [   64/ 6400]
# Validation Error: Accuracy: 57.1%, Avg loss: 1.136500
#
# Epoch 7
# -------------------------------
# loss: 1.207829  [   64/ 6400]
# Validation Error: Accuracy: 58.4%, Avg loss: 1.106628
#
# Epoch 8
# -------------------------------
# loss: 1.175298  [   64/ 6400]
# Validation Error: Accuracy: 59.4%, Avg loss: 1.078472
#
# Epoch 9
# -------------------------------
# loss: 1.143137  [   64/ 6400]
# Validation Error: Accuracy: 60.6%, Avg loss: 1.051840
#
# Epoch 10
# -------------------------------
# loss: 1.110983  [   64/ 6400]
# Validation Error: Accuracy: 62.3%, Avg loss: 1.026470
#
# Epoch 11
# -------------------------------
# loss: 1.078681  [   64/ 6400]
# Validation Error: Accuracy: 63.4%, Avg loss: 1.002299
#
# Epoch 12
# -------------------------------
# loss: 1.046397  [   64/ 6400]
# Validation Error: Accuracy: 64.4%, Avg loss: 0.979030
#
# Epoch 13
# -------------------------------
# loss: 1.014405  [   64/ 6400]
# Validation Error: Accuracy: 65.3%, Avg loss: 0.956579
#
# Epoch 14
# -------------------------------
# loss: 0.983044  [   64/ 6400]
# Validation Error: Accuracy: 66.6%, Avg loss: 0.934828
#
# Epoch 15
# -------------------------------
# loss: 0.952316  [   64/ 6400]
# Validation Error: Accuracy: 67.3%, Avg loss: 0.913742
#
# Epoch 16
# -------------------------------
# loss: 0.921985  [   64/ 6400]
# Validation Error: Accuracy: 67.9%, Avg loss: 0.893299
#
# Epoch 17
# -------------------------------
# loss: 0.892582  [   64/ 6400]
# Validation Error: Accuracy: 68.8%, Avg loss: 0.873516
#
# Epoch 18
# -------------------------------
# loss: 0.864475  [   64/ 6400]
# Validation Error: Accuracy: 69.4%, Avg loss: 0.854474
#
# Epoch 19
# -------------------------------
# loss: 0.837582  [   64/ 6400]
# Validation Error: Accuracy: 70.4%, Avg loss: 0.836083
#
# Epoch 20
# -------------------------------
# loss: 0.811957  [   64/ 6400]
# Validation Error: Accuracy: 70.9%, Avg loss: 0.818377
#
# Epoch 21
# -------------------------------
# loss: 0.787584  [   64/ 6400]
# Validation Error: Accuracy: 71.3%, Avg loss: 0.801382
#
# Epoch 22
# -------------------------------
# loss: 0.764459  [   64/ 6400]
# Validation Error: Accuracy: 72.0%, Avg loss: 0.785066
#
# Epoch 23
# -------------------------------
# loss: 0.742317  [   64/ 6400]
# Validation Error: Accuracy: 72.8%, Avg loss: 0.769384
#
# Epoch 24
# -------------------------------
# loss: 0.721221  [   64/ 6400]
# Validation Error: Accuracy: 73.3%, Avg loss: 0.754365
#
# Epoch 25
# -------------------------------
# loss: 0.701132  [   64/ 6400]
# Validation Error: Accuracy: 74.1%, Avg loss: 0.740002
#
# Epoch 26
# -------------------------------
# loss: 0.681821  [   64/ 6400]
# Validation Error: Accuracy: 74.6%, Avg loss: 0.726264
#
# Epoch 27
# -------------------------------
# loss: 0.663509  [   64/ 6400]
# Validation Error: Accuracy: 75.1%, Avg loss: 0.713084
#
# Epoch 28
# -------------------------------
# loss: 0.646065  [   64/ 6400]
# Validation Error: Accuracy: 75.8%, Avg loss: 0.700474
#
# Epoch 29
# -------------------------------
# loss: 0.629403  [   64/ 6400]
# Validation Error: Accuracy: 76.1%, Avg loss: 0.688335
#
# Epoch 30
# -------------------------------
# loss: 0.613439  [   64/ 6400]
# Validation Error: Accuracy: 76.8%, Avg loss: 0.676707
#
# Done!

# %%
test_loop(test_loader, model, "submission2.csv")
# Out:
# Saved predictions to submission2.csv
